# %% [markdown]
# # Review Summarization (API-based)
# ## Generating Recommendation Articles with ChatGPT / Claude
# ---
# **Objective:** Use generative AI to produce per-cluster and per-product summaries from customer reviews.
#
# **Outputs per cluster:**
# 1. Category overview article — top 3 products, key complaints, worst product
# 2. Individual product summaries — strengths, weaknesses, recommendation
#
# **API support:** OpenAI (GPT-4o-mini) and Anthropic (Claude Sonnet) — switch with a flag.

# %% [markdown]
# ## 1. Imports & Configuration

# %%
import os
import json
import time
import pandas as pd
import numpy as np
from dotenv import load_dotenv, find_dotenv

_ = load_dotenv(find_dotenv())

print("Libraries loaded")
# Out:
# Libraries loaded

# %%
# ============================================================
# SWITCH PROVIDER HERE
# ============================================================
PROVIDER = "anthropic"  # "openai" or "anthropic"

# Model selection
MODELS = {
    "openai": "gpt-4o-mini",
    "anthropic": "claude-sonnet-4-20250514"
}

# API keys from .env
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
ANTHROPIC_API_KEY = os.getenv("ANTHROPIC_API_KEY")

# Validate
if PROVIDER == "openai" and not OPENAI_API_KEY:
    raise ValueError("OPENAI_API_KEY not found in .env")
if PROVIDER == "anthropic" and not ANTHROPIC_API_KEY:
    raise ValueError("ANTHROPIC_API_KEY not found in .env")

print(f"Provider: {PROVIDER}")
print(f"Model: {MODELS[PROVIDER]}")
# Out:
# Provider: anthropic
# Model: claude-sonnet-4-20250514

# %%
# Initialize client based on provider
if PROVIDER == "openai":
    from openai import OpenAI
    client = OpenAI(api_key=OPENAI_API_KEY)
    
    def call_llm(system_prompt, user_prompt, max_tokens=2000):
        response = client.chat.completions.create(
            model=MODELS["openai"],
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ],
            max_tokens=max_tokens,
            temperature=0.3
        )
        return response.choices[0].message.content

elif PROVIDER == "anthropic":
    import anthropic
    client = anthropic.Anthropic(api_key=ANTHROPIC_API_KEY)
    
    def call_llm(system_prompt, user_prompt, max_tokens=2000):
        response = client.messages.create(
            model=MODELS["anthropic"],
            system=system_prompt,
            messages=[
                {"role": "user", "content": user_prompt}
            ],
            max_tokens=max_tokens,
            temperature=0.3
        )
        return response.content[0].text

# Quick test
test = call_llm("You are a helpful assistant.", "Say 'API connection successful' and nothing else.")
print(test)
# Out:
# API connection successful

# %% [markdown]
# ## 2. Load Data

# %%
# Load clustered data
df = pd.read_csv("../data/data_with_clusters.csv")

print(f"Dataset: {len(df):,} reviews")
print(f"\nCluster distribution:")
print(df["cluster_name"].value_counts())
# Out:
# Dataset: 28,332 reviews
#
# Cluster distribution:
# cluster_name
# Fire Tablets             14396
# Batteries & Household    12086
# E-Readers                 1049
# Smart Speakers             632
# Accessories                138
# Media & Home                31
# Name: count, dtype: int64

# %%
# If predictions are available, load them too
try:
    pred_df = pd.read_csv("../data/data_with_predictions_v2.csv")
    # Merge predicted sentiment into main df
    if "predicted_label" in pred_df.columns:
        df["predicted_label"] = pred_df["predicted_label"]
        df["predicted_score"] = pred_df["predicted_score"]
        print("Loaded v2 predictions")
        print(df["predicted_label"].value_counts())
except FileNotFoundError:
    print("No predictions file found, using star-based sentiment")
    df["predicted_label"] = df["sentiment"].str.upper()
# Out:
# Loaded v2 predictions
# predicted_label
# POSITIVE    25476
# NEGATIVE     1648
# NEUTRAL      1208
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Prepare Review Data for Prompts
#
# We need to be smart about what we send to the API — we can't send all 28K reviews. Strategy:
# - Sample representative reviews per product (positive, negative, neutral)
# - Include aggregate stats (avg rating, sentiment distribution)
# - Prioritize longer, more informative reviews

# %%
def get_product_stats(product_df):
    """Compute summary stats for a product."""
    total = len(product_df)
    avg_rating = product_df["reviews.rating"].mean()
    
    sentiment_counts = product_df["predicted_label"].value_counts()
    pct_positive = sentiment_counts.get("POSITIVE", 0) / total * 100
    pct_negative = sentiment_counts.get("NEGATIVE", 0) / total * 100
    pct_neutral = sentiment_counts.get("NEUTRAL", 0) / total * 100
    
    return {
        "total_reviews": total,
        "avg_rating": round(avg_rating, 2),
        "pct_positive": round(pct_positive, 1),
        "pct_negative": round(pct_negative, 1),
        "pct_neutral": round(pct_neutral, 1)
    }


def sample_reviews(product_df, n_positive=5, n_negative=5, n_neutral=3, min_words=5):
    """Sample diverse reviews for a product, prioritizing longer reviews."""
    product_df = product_df.copy()
    product_df["text"] = product_df["reviews.text"].fillna("").astype(str)
    product_df["word_count"] = product_df["text"].str.split().str.len()
    
    # Filter out very short reviews
    product_df = product_df[product_df["word_count"] >= min_words]
    
    sampled = []
    
    for label, n in [("POSITIVE", n_positive), ("NEGATIVE", n_negative), ("NEUTRAL", n_neutral)]:
        subset = product_df[product_df["predicted_label"] == label]
        if len(subset) == 0:
            continue
        # Prioritize longer reviews (more informative)
        subset = subset.sort_values("word_count", ascending=False)
        sample = subset.head(n)
        for _, row in sample.iterrows():
            # Truncate very long reviews
            text = row["text"][:500]
            sampled.append(f"[{label}] (Rating: {row['reviews.rating']}) {text}")
    
    return sampled


print("Helper functions defined")
# Out:
# Helper functions defined

# %%
# Build cluster data structure
clusters = {}

for cluster_name in df["cluster_name"].unique():
    cluster_df = df[df["cluster_name"] == cluster_name]
    
    products = []
    for product_name in cluster_df["name"].unique():
        product_df = cluster_df[cluster_df["name"] == product_name]
        stats = get_product_stats(product_df)
        reviews = sample_reviews(product_df)
        
        products.append({
            "name": product_name,
            "stats": stats,
            "sample_reviews": reviews
        })
    
    # Sort by review count descending
    products.sort(key=lambda x: x["stats"]["total_reviews"], reverse=True)
    
    clusters[cluster_name] = {
        "products": products,
        "total_reviews": len(cluster_df),
        "total_products": len(products),
        "avg_rating": round(cluster_df["reviews.rating"].mean(), 2)
    }

# Summary
for name, data in clusters.items():
    print(f"{name}: {data['total_products']} products, {data['total_reviews']:,} reviews, "
          f"avg rating {data['avg_rating']}")
# Out:
# Batteries & Household: 7 products, 12,086 reviews, avg rating 4.45
# Media & Home: 8 products, 31 reviews, avg rating 4.39
# Smart Speakers: 9 products, 632 reviews, avg rating 4.54
# Accessories: 11 products, 138 reviews, avg rating 4.31
# E-Readers: 10 products, 1,049 reviews, avg rating 4.66
# Fire Tablets: 20 products, 14,396 reviews, avg rating 4.56

# %% [markdown]
# ## 4. Prompt Templates

# %%
SYSTEM_PROMPT = """You are a consumer product analyst writing recommendation articles based on real 
customer reviews. Write in a clear, professional tone. Base all claims on the review data provided.
Do not invent facts or reviews. If data is limited, say so."""


CLUSTER_SUMMARY_PROMPT = """Write a recommendation article for the "{cluster_name}" product category.

Category overview:
- {total_products} products
- {total_reviews:,} total customer reviews
- Average rating: {avg_rating}/5

Products in this category (sorted by review count):
{product_list}

Sample reviews from top products:
{sample_reviews}

Write the article with these sections:
1. **Category Overview** — Brief intro to this product category and overall customer satisfaction
2. **Top 3 Recommended Products** — Based on ratings, review count, and review sentiment. For each: name, why it's recommended, key strengths from reviews
3. **Common Complaints** — Top 3-5 recurring issues across the category based on negative reviews
4. **Worst Rated Product** — Which product has the most complaints and why
5. **Buying Recommendation** — Brief conclusion with advice for shoppers

Keep it under 600 words."""


PRODUCT_SUMMARY_PROMPT = """Write a concise product review summary for:

Product: {product_name}

Stats:
- Total reviews: {total_reviews}
- Average rating: {avg_rating}/5
- Positive: {pct_positive}%
- Negative: {pct_negative}%
- Neutral: {pct_neutral}%

Sample reviews:
{sample_reviews}

Write a summary with:
1. **Overall Verdict** — One sentence recommendation (Buy / Consider / Avoid)
2. **Strengths** — Top 3 positives from reviews
3. **Weaknesses** — Top 3 negatives from reviews
4. **Best For** — What type of buyer this product suits

Keep it under 200 words."""


print("Prompt templates defined")
# Out:
# Prompt templates defined

# %% [markdown]
# ## 5. Generate Cluster Summaries

# %%
def build_cluster_prompt(cluster_name, cluster_data):
    """Build the full prompt for a cluster summary."""
    # Product list with stats
    product_lines = []
    for p in cluster_data["products"]:
        s = p["stats"]
        product_lines.append(
            f"- {p['name'][:80]}: {s['total_reviews']} reviews, "
            f"avg {s['avg_rating']}/5, {s['pct_positive']}% positive, {s['pct_negative']}% negative"
        )
    product_list = "\n".join(product_lines)
    
    # Sample reviews from top 3 products (by review count)
    all_reviews = []
    for p in cluster_data["products"][:3]:
        all_reviews.append(f"\n--- {p['name'][:60]} ---")
        all_reviews.extend(p["sample_reviews"][:8])  # limit per product
    sample_reviews = "\n".join(all_reviews)
    
    return CLUSTER_SUMMARY_PROMPT.format(
        cluster_name=cluster_name,
        total_products=cluster_data["total_products"],
        total_reviews=cluster_data["total_reviews"],
        avg_rating=cluster_data["avg_rating"],
        product_list=product_list,
        sample_reviews=sample_reviews
    )


print("Prompt builder defined")
# Out:
# Prompt builder defined

# %%
# Generate cluster summaries
cluster_summaries = {}

for cluster_name, cluster_data in clusters.items():
    print(f"\nGenerating summary for: {cluster_name}...")
    
    prompt = build_cluster_prompt(cluster_name, cluster_data)
    
    try:
        summary = call_llm(SYSTEM_PROMPT, prompt, max_tokens=1500)
        cluster_summaries[cluster_name] = summary
        print(f"  Done ({len(summary)} chars)")
    except Exception as e:
        print(f"  ERROR: {e}")
        cluster_summaries[cluster_name] = f"Error generating summary: {e}"
    
    time.sleep(1)  # rate limit courtesy

print(f"\nGenerated {len(cluster_summaries)} cluster summaries")
# Out:
# Generating summary for: Batteries & Household...
#   Done (3816 chars)
#
# Generating summary for: Media & Home...
#   Done (3763 chars)
#
# Generating summary for: Smart Speakers...
#   Done (3928 chars)
#
# Generating summary for: Accessories...
#   Done (3422 chars)
#
# Generating summary for: E-Readers...
#   Done (3714 chars)
#
# Generating summary for: Fire Tablets...
#   Done (3794 chars)
#
# Generated 6 cluster summaries

# %%
# Display cluster summaries
for cluster_name, summary in cluster_summaries.items():
    print("=" * 70)
    print(f"CLUSTER: {cluster_name}")
    print("=" * 70)
    print(summary)
    print()
# Out:
# ======================================================================
# CLUSTER: Batteries & Household
# ======================================================================
# # Batteries & Household Products: Customer Review Analysis
#
# ## Category Overview
#
# The Batteries & Household category features 7 diverse products with over 12,000 customer reviews and a solid 4.45/5 average rating. While the category name suggests batteries and household items, the actual products range from alkaline batteries to pet supplies and office organizers. Customer satisfaction is generally high, with most products receiving positive feedback for value and performance.
#
# ## Top 3 Recommended Products
#
# **1. AmazonBasics AAA Performance Alkaline Batteries (36 Count)**
# With 8,343 reviews and 4.45/5 stars, these batteries earn top marks for capacity and value. Customers consistently praise their performance compared to name brands like Duracell, with one reviewer noting they're "tied for the top spot" in capacity testing. The convenient packaging—batteries grouped in sets of four—prevents the common problem of loose batteries cluttering drawers.
#
# **2. AmazonBasics AA Performance Alkaline Batteries (48 Count)**
# Nearly matching the AAA version with 3,728 reviews and identical ratings, these AA batteries offer exceptional value at roughly 25 cents per battery versus 50-58 cents for Duracell and Energizer. Customers appreciate the organized packaging and report performance "almost as long" as premium brands at half the cost.
#
# **3. Expanding Accordion File Folder**
# Though with limited data (9 reviews), this product achieves a perfect 5.0/5 rating. Customers highlight its expandable bottom design, portability, and sturdy construction. Multiple reviewers recommend it to friends, praising the combination of good quality and affordable pricing.
#
# ## Common Complaints
#
# **Battery Leakage**: The most serious recurring issue involves battery acid leakage, with multiple customers reporting damage to devices including keyboards and toys. Some batteries leaked within days of installation, even in unused devices.
#
# **Inconsistent Quality Control**: Several customers received batteries that were "marginal/undervoltage" straight from the package, with some measuring below the expected 1.5V capacity.
#
# **Fit Issues**: Some users experienced problems with batteries not fitting properly in certain devices, despite testing at full charge and having clean contacts.
#
# **Premature Failure**: A subset of customers reported batteries dying much faster than expected, with some describing them as the "worst batteries ever encountered."
#
# **Limited Product Data**: For non-battery items, extremely low review counts (1-9 reviews) make it difficult to assess long-term reliability and performance.
#
# ## Worst Rated Product
#
# The **AmazonBasics Double-Door Folding Metal Dog Crate (Medium)** has the lowest rating at 3.5/5 stars, though with only 2 reviews, this assessment is based on very limited data. The 50% positive rate suggests potential quality or functionality issues, but more customer feedback would be needed for a definitive evaluation.
#
# ## Buying Recommendation
#
# For batteries, AmazonBasics offers compelling value with performance nearly matching premium brands at significantly lower costs. However, be aware of potential quality control issues—inspect batteries before use and avoid leaving them in unused devices for extended periods.
#
# The accordion file folder appears to be a solid choice based on available reviews, though the limited feedback suggests proceeding with typical caution for lesser-known products.
#
# For pet supplies in this category, the extremely low review counts make it difficult to provide confident recommendations. Consider looking for similar products with more substantial customer feedback.
#
# Overall, this category delivers good value, particularly for batteries, but quality control inconsistencies mean buyers should be prepared for occasional defective units.
#
# ======================================================================
# CLUSTER: Media & Home
# ======================================================================
# # Media & Home Products: Customer Review Analysis & Recommendations
#
# ## Category Overview
#
# The Media & Home category features 8 products with 31 customer reviews and a strong average rating of 4.39/5 stars. This category spans entertainment devices, storage solutions, and home accessories, offering customers a diverse range of options for their media and household needs. Overall customer satisfaction is high, though individual product performance varies significantly.
#
# ## Top 3 Recommended Products
#
# ### 1. Fire TV Stick Streaming Media Player Pair Kit
# **Rating: 5.0/5 (6 reviews) | 100% positive**
#
# This streaming device stands out as the clear category winner with perfect ratings across all reviews. Customers consistently praise its ability to replace expensive cable subscriptions, with one reviewer noting savings from a $172 cable bill to just $59 monthly for streaming services. Key strengths include reliable performance, easy setup, and extensive app compatibility. Users particularly appreciate access to free streaming services like TubiTV and the ability to use existing cable login credentials for premium content.
#
# ### 2. Amazon Fire TV Gaming Edition Streaming Media Player
# **Rating: 4.67/5 (3 reviews) | 100% positive**
#
# Despite having fewer reviews, this gaming-focused streaming device maintains perfect positive sentiment. While specific review details are limited, the consistently high ratings suggest strong customer satisfaction with its gaming and streaming capabilities.
#
# ### 3. AmazonBasics External Hard Drive Case
# **Rating: 4.5/5 (6 reviews) | 83.3% positive**
#
# This protective case earns strong customer approval for its build quality and perfect fit for popular external drives like the Western Digital My Passport. Reviewers highlight the sturdy construction, exact product match to listings, and adequate space for USB cables. One customer noted it provides essential protection for drives storing important photos.
#
# ## Common Complaints
#
# Based on available negative feedback, the most frequent issues include:
#
# 1. **Setup difficulties** - Multiple Fire TV Stick users reported challenging installation processes, particularly with HDMI port accessibility and initial configuration requiring multiple support calls
# 2. **Product discrepancies** - Some customers received items that didn't match product photos exactly
# 3. **Limited functionality** - Certain features like mirror casting didn't work as expected on some devices
# 4. **Mixed review quality** - Some reviews lack sufficient detail to assess product performance accurately
#
# ## Worst Rated Product
#
# **Certified Refurbished Amazon Fire TV with Alexa Voice Remote (2.8/5, 40% positive)**
#
# This refurbished streaming device has the lowest rating and highest negative sentiment in the category. With only 40% positive reviews and 40% negative feedback, customers appear significantly less satisfied compared to the new Fire TV Stick model. The refurbished nature may contribute to reliability or performance issues, though specific complaint details weren't provided in the sample data.
#
# ## Buying Recommendation
#
# For streaming devices, the Fire TV Stick Streaming Media Player Pair Kit offers exceptional value with perfect customer satisfaction and proven cable-cutting capabilities. Avoid the refurbished Fire TV model due to poor ratings.
#
# For storage protection, the AmazonBasics External Hard Drive Case provides reliable protection at a competitive price point, though verify the product matches current listings.
#
# Given the limited review data (only 31 reviews across 8 products), consider seeking additional reviews from other sources before making final purchasing decisions. Focus on products with higher review counts for more reliable performance indicators.
#
# ======================================================================
# CLUSTER: Smart Speakers
# ======================================================================
# # Smart Speakers: Customer Review Analysis & Recommendations
#
# ## Category Overview
#
# Smart speakers have gained significant traction among consumers, with this category showing strong overall satisfaction. Based on 632 customer reviews across 9 products, the category maintains an impressive 4.54/5 average rating, indicating that most buyers are pleased with their smart speaker purchases. The Amazon Echo ecosystem dominates this category, with various generations and models available to suit different needs and budgets.
#
# ## Top 3 Recommended Products
#
# **1. Amazon Tap Smart Assistant Alexa-enabled (Black)**
# With 601 reviews and a 4.54/5 rating, this is the clear category leader. Customers consistently praise its excellent sound quality as a Bluetooth speaker, portability with 9-hour battery life, and convenient charging dock. Reviewers highlight its versatility for both music streaming and smart home control, with one noting they successfully set up lamp control within 5 minutes. The portable design makes it ideal for users who want to move their smart speaker between rooms.
#
# **2. Certified Refurbished Amazon Echo**
# Despite having only 7 reviews, this product achieves a perfect 5.0/5 rating with 100% positive feedback. Customers appreciate the value proposition of getting first-generation Echo functionality at a lower price point. Reviewers specifically mention superior sound quality that "fills the room" and reliable connectivity compared to smaller alternatives like the Echo Dot.
#
# **3. Amazon Echo (1st Generation) - White**
# With 13 reviews and a 4.31/5 rating, this original Echo model receives strong endorsements from customers who own multiple Echo devices. Users praise its quick response times, effectiveness for creating shared shopping lists, and expanding skill set. The always-listening feature is particularly valued for hands-free operation.
#
# ## Common Complaints
#
# **1. Amazon Prime Dependency**: Multiple reviewers express frustration that many features require an Amazon Prime subscription, with one customer returning their device due to unexpected subscription requirements.
#
# **2. Limited Music Streaming Options**: Several customers report difficulties streaming music directly from their phones, requiring additional app downloads and setup steps that weren't clearly communicated.
#
# **3. Voice Recognition Limitations**: Users frequently mention that Alexa requires very specific phrasing for commands and often responds with "I don't understand the question" for more complex queries.
#
# **4. Connectivity Issues**: Some customers experience problems with Wi-Fi connectivity and Bluetooth pairing, particularly with the Tap model cutting in and out during online radio streaming.
#
# **5. Button-Press Requirement**: For the Tap model specifically, the need to press a button for each voice command disappoints customers expecting hands-free operation like other Echo devices.
#
# ## Worst Rated Product
#
# The Amazon Echo (1st Generation) has the lowest satisfaction rate at 84.6% positive reviews, with 15.4% negative feedback. The primary complaints center on Alexa's limited ability to answer complex questions and the learning curve required for proper command phrasing. However, it's worth noting that even this "worst" product maintains a respectable 4.31/5 rating.
#
# ## Buying Recommendation
#
# Smart speakers in this category generally deliver strong value, with the Amazon Tap being the standout choice for most buyers due to its portability and excellent audio quality. If you prioritize hands-free operation, consider the traditional Echo models over the Tap. Before purchasing, ensure you're comfortable with Amazon Prime integration for full functionality, and be prepared for a setup period to learn optimal voice commands. The consistently high ratings across products suggest most buyers will be satisfied with their smart speaker investment, regardless of which model they choose.
#
# ======================================================================
# CLUSTER: Accessories
# ======================================================================
# # Accessories Category Review: Essential Tech Companions with Strong Performance
#
# The Accessories category offers 11 essential tech products ranging from chargers to laptop bags, with 138 customer reviews averaging a solid 4.31/5 stars. This category demonstrates consistent quality across most products, though some charging accessories show notable quality variations.
#
# ## Top 3 Recommended Products
#
# **1. Amazon 9W PowerFast Official OEM USB Charger and Power Adapter**
# With 39 reviews and a 4.67/5 rating, this charger leads the category in both popularity and performance. Customers appreciate its reliability and device-specific design, with one reviewer noting how using non-OEM chargers can damage tablets. The fast-charging capability and travel-friendly design make it ideal for Kindle users, though some wish it came bundled with devices.
#
# **2. AmazonBasics 15.6-Inch Laptop and Tablet Bag**
# Earning 4.52/5 stars across 21 reviews, this laptop bag impresses with its build quality and functionality. Reviewers consistently praise its "well-constructed" design, ample storage compartments, and protective padding. One customer noted it works equally well as a briefcase, highlighting its versatility beyond laptop transport.
#
# **3. AmazonBasics USB 3.0 Cable - A-Male to B-Male**
# Though with fewer reviews (6), this cable achieves a perfect 5.0/5 rating with 100% positive feedback. Its flawless performance record makes it a reliable choice for users needing dependable USB connectivity.
#
# ## Common Complaints
#
# **Durability Concerns**: Multiple charger products show longevity issues, with one reviewer noting they "only work for a year before needing to be replaced."
#
# **Missing Essential Components**: Several customers expressed frustration that wall chargers don't include cables, requiring separate purchases for complete functionality.
#
# **Material Quality**: The AmazonBasics backpack receives criticism for its "crinkly" interior lining and "cheap-feeling" materials, despite good overall construction.
#
# **Size Limitations**: Some laptop bags and sleeves don't accommodate larger devices as advertised, with one reviewer noting their 17-inch laptop didn't fit the supposedly compatible backpack.
#
# **Limited Openings**: Laptop bags with restricted zipper openings make device insertion and removal cumbersome, as noted by multiple reviewers.
#
# ## Worst Rated Product
#
# **OEM Amazon Kindle Power USB Adapter Wall Travel Charger** stands out as the category's biggest disappointment with a 1.0/5 rating and 100% negative reviews across 4 evaluations. This third-party charger appears to have significant quality and compatibility issues, making it a clear product to avoid.
#
# ## Buying Recommendation
#
# The Accessories category offers reliable options for most tech needs, with official Amazon and AmazonBasics products generally delivering solid value. Prioritize OEM chargers like the Amazon 9W PowerFast for device safety, and consider the AmazonBasics laptop bag for dependable protection with multiple storage options.
#
# However, exercise caution with third-party charging accessories and carefully verify size compatibility for laptop bags. While some products show minor material quality compromises, the overall category provides functional, affordable solutions for everyday tech accessory needs. Focus on products with higher review counts and official Amazon branding for the most reliable experience.
#
# ======================================================================
# CLUSTER: E-Readers
# ======================================================================
# # E-Readers: A Comprehensive Buying Guide Based on Customer Reviews
#
# ## Category Overview
#
# E-readers continue to deliver exceptional customer satisfaction, with 1,049 reviews across 10 products yielding an impressive 4.66/5 average rating. This mature product category is dominated by Kindle devices, which consistently earn high marks for their core reading functionality, battery life, and screen quality. The overwhelmingly positive feedback (94%+ positive ratings across most products) indicates that modern e-readers have successfully addressed the fundamental needs of digital readers.
#
# ## Top 3 Recommended Products
#
# **1. Kindle Voyage E-reader (6" High-Resolution Display)**
# *505 reviews, 4.73/5 rating, 96.8% positive*
#
# The clear category leader, praised for its automatic brightness adjustment and superior screen quality. Customers consistently highlight its lightweight design, fast performance, and excellent readability in all lighting conditions. One reviewer noted it's "by far the best Kindle yet" with operation that's "lighter and faster and very comfortable in the hand."
#
# **2. Kindle E-reader - White (6" Glare-Free Touchscreen)**
# *287 reviews, 4.54/5 rating, 93.7% positive*
#
# The best value option that "does its job properly." Customers appreciate its simplicity, excellent battery life, and portability. Reviews emphasize its effectiveness for basic reading needs, with one customer noting they "managed to read a book a week" since getting it. The lack of backlighting is seen as both a cost-saving feature and eye-strain reducer.
#
# **3. Kindle Oasis with Leather Charging Cover - Walnut**
# *62 reviews, 4.61/5 rating, 96.8% positive*
#
# Premium users love its crystal-clear display that remains readable "even in bright sunlight" and the return of physical page-turn buttons. The compact, lightweight design makes it comfortable for extended reading sessions, whether "pacing the floor" or exercising.
#
# ## Common Complaints
#
# Based on negative reviews, the most frequent issues include:
#
# 1. **Screen discoloration** - Multiple Voyage users report yellowish tinge at the top and bluish hue at the bottom of the display
# 2. **Charging problems** - Several customers experienced devices that won't charge or hold a charge after minimal use
# 3. **Software update failures** - Some devices became unresponsive after mandatory software updates
# 4. **Fragile screens** - Accidental damage appears common, with limited warranty coverage for user-caused breaks
# 5. **Inconsistent customer service** - Mixed experiences with Amazon support for device replacements and repairs
#
# ## Worst Rated Product
#
# The All-New Kindle Oasis (7" display, waterproof) with 22 reviews shows the highest negative rating percentage at 9.1%, though the sample size is relatively small. However, the standard Kindle E-reader models show more concerning patterns with charging failures and screen issues reported across multiple units.
#
# ## Buying Recommendation
#
# For most readers, the **Kindle Voyage** offers the best balance of features and reliability, despite some screen uniformity issues. Budget-conscious buyers should consider the **basic Kindle E-reader**, which delivers solid performance for essential reading needs.
#
# Premium users willing to pay more should opt for the **Kindle Oasis with charging cover**, but be aware of the two-piece design's potential inconvenience. Regardless of model choice, consider purchasing from retailers with strong return policies, as quality control issues, while uncommon, can be frustrating when they occur.
#
# The category's high satisfaction rates suggest most buyers will be pleased with their purchase, but factor in potential screen and charging issues when making your decision.
#
# ======================================================================
# CLUSTER: Fire Tablets
# ======================================================================
# # Fire Tablets: A Comprehensive Buying Guide Based on Customer Reviews
#
# ## Category Overview
#
# Fire Tablets represent Amazon's budget-friendly entry into the tablet market, with 20 different models earning an impressive 4.56/5 average rating across 14,396 customer reviews. The category shows strong customer satisfaction, with most models achieving over 90% positive reviews, making them a compelling choice for budget-conscious consumers seeking basic tablet functionality.
#
# ## Top 3 Recommended Products
#
# **1. Fire HD 8 Tablet with Alexa (16GB, Tangerine)**
# With 2,443 reviews and a 4.6/5 rating, this model leads in both popularity and satisfaction. Customers praise its excellent value at around $89, calling it "fast at everything except gameplay" with "great stereo speakers." The 8" HD display receives consistent praise for movies and reading, though some note it struggles with direct sunlight.
#
# **2. All-New Fire HD 8 Tablet (16GB)**
# Nearly matching the top model with 2,370 reviews and 4.58/5 rating, customers highlight its superior screen quality compared to the 7" models and adequate performance for web browsing and streaming. Parents particularly appreciate the FreeTime parental controls available across Fire models.
#
# **3. Fire Kids Edition Tablet (7" Display, Pink)**
# Leading the kids' category with 1,676 reviews and 4.53/5 rating, this tablet stands out for its exceptional durability. Parents rave about the "thick, heavy duty" protective case that withstands drops, bites, and rough handling. The 2-year no-questions-asked replacement warranty, including cracked screens, receives universal praise.
#
# ## Common Complaints
#
# **Limited App Selection**: The most frequent complaint involves Amazon's restricted app store versus Google Play Store. Many customers discover popular apps aren't available, though tech-savvy users note Google Play can be manually installed.
#
# **Performance Issues**: Users report slow performance, particularly with gaming and screen rotation, with some describing 7-10 second delays for basic functions.
#
# **Charging Port Problems**: Multiple reviews mention chronic charging port failures, especially on Kids Edition models, with some devices failing to charge shortly after purchase.
#
# **Display Quality in Sunlight**: Several customers note the screen becomes difficult to read in direct sunlight, limiting outdoor usability.
#
# **Storage Management**: Confusion between RAM and storage, plus issues with microSD card recognition across different formats (FAT32, NTFS).
#
# ## Worst Rated Product
#
# While no single product stands out as significantly worse-rated, the Fire Kids Edition models show slightly higher complaint rates (3.2-3.5% negative reviews) primarily due to charging port failures and the frustration of discovering app limitations after purchase. The charging issues are particularly problematic given these tablets' target audience of young children.
#
# ## Buying Recommendation
#
# Fire Tablets excel as budget-friendly devices for basic tasks like reading, streaming, and light web browsing, especially for Amazon Prime members who can access free content. The HD 8 models offer the best balance of performance and value for general use.
#
# Choose Kids Edition models only if you need the rugged case and parental controls – the 2-year replacement warranty provides excellent peace of mind despite some charging port issues. However, avoid Fire Tablets if you need access to the full Google Play Store ecosystem or plan to use graphics-intensive applications.
#
# For the best experience, consider the 32GB models if available in your budget, as the 16GB versions may feel limiting with app installations and media storage. Overall, these tablets deliver solid value for their price point, provided you understand their limitations upfront.

# %% [markdown]
# ## 6. Generate Product Summaries
#
# Generate individual summaries only for products with enough reviews to be meaningful (>= 20 reviews).

# %%
MIN_REVIEWS_FOR_PRODUCT_SUMMARY = 20

# Count eligible products
eligible = []
for cluster_name, cluster_data in clusters.items():
    for p in cluster_data["products"]:
        if p["stats"]["total_reviews"] >= MIN_REVIEWS_FOR_PRODUCT_SUMMARY:
            eligible.append((cluster_name, p))

print(f"Products eligible for individual summary (>= {MIN_REVIEWS_FOR_PRODUCT_SUMMARY} reviews): {len(eligible)}")
for cluster, p in eligible:
    print(f"  [{cluster}] {p['name'][:60]}... ({p['stats']['total_reviews']} reviews)")
# Out:
# Products eligible for individual summary (>= 20 reviews): 33
#   [Batteries & Household] AmazonBasics AAA Performance Alkaline Batteries (36 Count)... (8343 reviews)
#   [Batteries & Household] AmazonBasics AA Performance Alkaline Batteries (48 Count) - ... (3728 reviews)
#   [Smart Speakers] Amazon Tap Smart Assistant Alexaenabled (black) Brand New... (601 reviews)
#   [Accessories] Amazon 9W PowerFast Official OEM USB Charger and Power Adapt... (39 reviews)
#   [Accessories] AmazonBasics Backpack for Laptops up to 17-inches... (25 reviews)
#   [Accessories] AmazonBasics 15.6-Inch Laptop and Tablet Bag... (21 reviews)
#   [E-Readers] Kindle Voyage E-reader, 6 High-Resolution Display (300 ppi) ... (505 reviews)
#   [E-Readers] Kindle E-reader - White, 6 Glare-Free Touchscreen Display, W... (287 reviews)
#   [E-Readers] Kindle Oasis E-reader with Leather Charging Cover - Walnut, ... (62 reviews)
#   [E-Readers] Kindle Oasis E-reader with Leather Charging Cover - Black, 6... (55 reviews)
#   [E-Readers] Kindle Oasis E-reader with Leather Charging Cover - Merlot, ... (54 reviews)
#   [E-Readers] Kindle Voyage E-reader, 6 High-Resolution Display (300 ppi) ... (36 reviews)
#   [E-Readers] All-New Kindle Oasis E-reader - 7 High-Resolution Display (3... (22 reviews)
#   [Fire Tablets] Fire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Tangerine ... (2443 reviews)
#   [Fire Tablets] All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Inclu... (2370 reviews)
#   [Fire Tablets] Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Pink Kid-... (1676 reviews)
#   [Fire Tablets] Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Blue Kid-... (1425 reviews)
#   [Fire Tablets] Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Green Kid... (1212 reviews)
#   [Fire Tablets] Fire Tablet, 7 Display, Wi-Fi, 16 GB - Includes Special Offe... (1024 reviews)
#   [Fire Tablets] Fire Tablet with Alexa, 7 Display, 16 GB, Blue - with Specia... (987 reviews)
#   [Fire Tablets] All-New Fire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Ma... (883 reviews)
#   [Fire Tablets] Fire Tablet with Alexa, 7 Display, 16 GB, Magenta - with Spe... (745 reviews)
#   [Fire Tablets] All-New Fire HD 8 Kids Edition Tablet, 8 HD Display, 32 GB, ... (293 reviews)
#   [Fire Tablets] All-New Fire HD 8 Kids Edition Tablet, 8 HD Display, 32 GB, ... (233 reviews)
#   [Fire Tablets] All-New Fire HD 8 Tablet with Alexa, 8 HD Display, 32 GB, Ma... (160 reviews)
#   [Fire Tablets] All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Inclu... (156 reviews)
#   [Fire Tablets] Fire HD 8 Tablet with Alexa, 8 HD Display, 32 GB, Tangerine ... (156 reviews)
#   [Fire Tablets] All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Inclu... (140 reviews)
#   [Fire Tablets] Amazon Fire HD 8 with Alexa (8" HD Display Tablet)... (130 reviews)
#   [Fire Tablets] All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Inclu... (115 reviews)
#   [Fire Tablets] Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 GB - Includes ... (99 reviews)
#   [Fire Tablets] All-New Fire 7 Tablet with Alexa, 7" Display, 8 GB - Marine ... (82 reviews)
#   [Fire Tablets] All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Inclu... (67 reviews)

# %%
# Generate product summaries
product_summaries = {}

for cluster_name, product in eligible:
    product_name = product["name"]
    stats = product["stats"]
    
    print(f"Generating: {product_name[:50]}...")
    
    prompt = PRODUCT_SUMMARY_PROMPT.format(
        product_name=product_name,
        total_reviews=stats["total_reviews"],
        avg_rating=stats["avg_rating"],
        pct_positive=stats["pct_positive"],
        pct_negative=stats["pct_negative"],
        pct_neutral=stats["pct_neutral"],
        sample_reviews="\n".join(product["sample_reviews"])
    )
    
    try:
        summary = call_llm(SYSTEM_PROMPT, prompt, max_tokens=600)
        product_summaries[product_name] = {
            "cluster": cluster_name,
            "stats": stats,
            "summary": summary
        }
        print(f"  Done ({len(summary)} chars)")
    except Exception as e:
        print(f"  ERROR: {e}")
        product_summaries[product_name] = {
            "cluster": cluster_name,
            "stats": stats,
            "summary": f"Error: {e}"
        }
    
    time.sleep(0.5)  # rate limit

print(f"\nGenerated {len(product_summaries)} product summaries")
# Out:
# Generating: AmazonBasics AAA Performance Alkaline Batteries (3...
#   Done (1341 chars)
# Generating: AmazonBasics AA Performance Alkaline Batteries (48...
#   Done (1363 chars)
# Generating: Amazon Tap Smart Assistant Alexaenabled (black) Br...
#   Done (1370 chars)
# Generating: Amazon 9W PowerFast Official OEM USB Charger and P...
#   Done (1324 chars)
# Generating: AmazonBasics Backpack for Laptops up to 17-inches...
#   Done (1260 chars)
# Generating: AmazonBasics 15.6-Inch Laptop and Tablet Bag...
#   Done (1358 chars)
# Generating: Kindle Voyage E-reader, 6 High-Resolution Display ...
#   Done (1307 chars)
# Generating: Kindle E-reader - White, 6 Glare-Free Touchscreen ...
#   Done (1370 chars)
# Generating: Kindle Oasis E-reader with Leather Charging Cover ...
#   Done (1360 chars)
# Generating: Kindle Oasis E-reader with Leather Charging Cover ...
#   Done (1327 chars)
# Generating: Kindle Oasis E-reader with Leather Charging Cover ...
#   Done (1337 chars)
# Generating: Kindle Voyage E-reader, 6 High-Resolution Display ...
#   Done (1381 chars)
# Generating: All-New Kindle Oasis E-reader - 7 High-Resolution ...
#   Done (1347 chars)
# Generating: Fire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, ...
#   Done (1317 chars)
# Generating: All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 ...
#   Done (1341 chars)
# Generating: Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB,...
#   Done (1397 chars)
# Generating: Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB,...
#   Done (1393 chars)
# Generating: Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB,...
#   Done (1416 chars)
# Generating: Fire Tablet, 7 Display, Wi-Fi, 16 GB - Includes Sp...
#   Done (1344 chars)
# Generating: Fire Tablet with Alexa, 7 Display, 16 GB, Blue - w...
#   Done (1345 chars)
# Generating: All-New Fire HD 8 Tablet with Alexa, 8 HD Display,...
#   Done (1350 chars)
# Generating: Fire Tablet with Alexa, 7 Display, 16 GB, Magenta ...
#   Done (1313 chars)
# Generating: All-New Fire HD 8 Kids Edition Tablet, 8 HD Displa...
#   Done (1346 chars)
# Generating: All-New Fire HD 8 Kids Edition Tablet, 8 HD Displa...
#   Done (1332 chars)
# Generating: All-New Fire HD 8 Tablet with Alexa, 8 HD Display,...
#   Done (1350 chars)
# Generating: All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 ...
#   Done (1291 chars)
# Generating: Fire HD 8 Tablet with Alexa, 8 HD Display, 32 GB, ...
#   Done (1354 chars)
# Generating: All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 ...
#   Done (1292 chars)
# Generating: Amazon Fire HD 8 with Alexa (8" HD Display Tablet)...
#   Done (1361 chars)
# Generating: All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 ...
#   Done (1326 chars)
# Generating: Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 GB -...
#   Done (1297 chars)
# Generating: All-New Fire 7 Tablet with Alexa, 7" Display, 8 GB...
#   Done (1187 chars)
# Generating: All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 ...
#   Done (1318 chars)
#
# Generated 33 product summaries

# %%
# Display product summaries
for product_name, data in product_summaries.items():
    print("=" * 70)
    print(f"PRODUCT: {product_name[:70]}")
    print(f"Cluster: {data['cluster']} | Reviews: {data['stats']['total_reviews']} | "
          f"Rating: {data['stats']['avg_rating']}/5")
    print("-" * 70)
    print(data["summary"])
    print()
# Out:
# ======================================================================
# PRODUCT: AmazonBasics AAA Performance Alkaline Batteries (36 Count)
# Cluster: Batteries & Household | Reviews: 8343 | Rating: 4.45/5
# ----------------------------------------------------------------------
# ## AmazonBasics AAA Performance Alkaline Batteries Review Summary
#
# **Overall Verdict:** Consider these batteries for basic household needs, but be aware of quality control issues.
#
# **Strengths:**
# 1. **Excellent value** - Competitive capacity per dollar compared to name brands, with convenient bulk packaging
# 2. **Smart packaging design** - Batteries come in easy-access cardboard box that prevents spills, unlike traditional blister packs
# 3. **Good performance in low-drain devices** - Reliable for keyboards, mice, and remote controls with steady power draw
#
# **Weaknesses:**
# 1. **Quality control problems** - Multiple reports of dead or undervoltage batteries straight from the package
# 2. **Battery leakage issues** - Several customers experienced acid leakage that damaged devices
# 3. **Poor performance in high-drain applications** - Significantly shorter lifespan in toys, LED lights, and other power-hungry electronics
#
# **Best For:** Budget-conscious consumers who primarily use batteries in low-drain devices like TV remotes, wireless keyboards, and computer mice. Not recommended for high-drain electronics, children's toys, or critical applications where reliability is essential. The 85% positive rating suggests most users are satisfied, but the leakage reports warrant caution.
#
# *Based on 8,343 reviews with 4.45/5 average rating*
#
# ======================================================================
# PRODUCT: AmazonBasics AA Performance Alkaline Batteries (48 Count) - Packaging
# Cluster: Batteries & Household | Reviews: 3728 | Rating: 4.45/5
# ----------------------------------------------------------------------
# ## AmazonBasics AA Performance Alkaline Batteries (48 Count) Review Summary
#
# **Overall Verdict:** Buy - These batteries offer excellent value for money with reliable performance for most household needs.
#
# **Strengths:**
# 1. **Outstanding value** - At approximately 25 cents per battery, they significantly undercut name brands like Duracell (50¢) and Energizer (58¢) while delivering comparable performance
# 2. **Good capacity and longevity** - Multiple reviewers confirmed they perform nearly as well as premium brands in capacity tests, lasting almost as long as Duracell batteries
# 3. **Convenient packaging** - Batteries arrive well-organized in groups of four with plastic wrapping, making storage and use easy
#
# **Weaknesses:**
# 1. **Leakage issues** - Several reviewers reported battery acid leakage, sometimes damaging devices or creating safety concerns
# 2. **Inconsistent fit** - Some users experienced problems with batteries not fitting properly in certain devices, despite standard sizing
# 3. **Shorter lifespan in high-drain devices** - Performance drops more noticeably compared to premium brands when used in power-hungry electronics
#
# **Best For:** Budget-conscious households needing batteries for low-to-moderate drain devices like remotes, toys, and flashlights. Families who use many batteries will appreciate the bulk pricing and decent performance.
#
# ======================================================================
# PRODUCT: Amazon Tap Smart Assistant Alexaenabled (black) Brand New
# Cluster: Smart Speakers | Reviews: 601 | Rating: 4.54/5
# ----------------------------------------------------------------------
# ## Amazon Tap Smart Assistant Review Summary
#
# **Overall Verdict:** Consider this device if you prioritize portability over always-on voice activation, as it excels as a Bluetooth speaker but has notable smart assistant limitations.
#
# **Strengths:**
# 1. **Excellent portable audio quality** - Multiple reviewers praised the sound quality as a Bluetooth speaker, with clear audio and no streaming stutters
# 2. **True portability with long battery life** - 6-9 hour battery life with convenient charging dock makes it ideal for room-to-room use
# 3. **Full Alexa integration when activated** - Offers complete smart home control and music streaming capabilities once the button is pressed
#
# **Weaknesses:**
# 1. **Requires button press for voice commands** - Unlike other Echo devices, you must physically tap the device each time, reducing convenience
# 2. **Setup complexity and connectivity issues** - Several users reported difficulty connecting to phones and requiring additional app downloads
# 3. **Audio quality degrades at higher volumes** - Bass becomes weak at loud volumes, disappointing compared to dedicated Bluetooth speakers
#
# **Best For:** Existing Amazon Echo users who want a portable extension of their smart home system, or those who primarily want a quality Bluetooth speaker with occasional voice assistant features and don't mind the tap-to-activate requirement.
#
# ======================================================================
# PRODUCT: Amazon 9W PowerFast Official OEM USB Charger and Power Adapter for Fir
# Cluster: Accessories | Reviews: 39 | Rating: 4.67/5
# ----------------------------------------------------------------------
# ## Amazon 9W PowerFast USB Charger Review Summary
#
# **Overall Verdict:** Buy - This official charger delivers reliable performance with an impressive 4.67/5 rating, though it feels like an essential accessory that should be included with devices.
#
# **Strengths:**
# 1. **Device Compatibility & Safety** - Multiple reviews emphasize using the official charger prevents potential damage that third-party chargers might cause to Fire tablets and Kindles
# 2. **Reliable Fast Charging** - Users report quick, consistent charging performance that works when other chargers fail
# 3. **Travel Convenience** - Compact wall adapter design makes it ideal for travel and charging away from computers
#
# **Weaknesses:**
# 1. **Should Be Included** - Most common complaint is that this essential charger isn't bundled with Kindle devices, forcing separate purchase
# 2. **Durability Concerns** - Some users report needing replacements after about a year, with one reviewer on their third unit
# 3. **Charging Speed Expectations** - At least one user found it didn't charge as fast as the "PowerFast" name suggested
#
# **Best For:** Kindle and Fire tablet owners who need a reliable wall charger for home or travel use, especially those who've experienced issues with generic chargers or want the peace of mind that comes with official Amazon accessories.
#
# ======================================================================
# PRODUCT: AmazonBasics Backpack for Laptops up to 17-inches
# Cluster: Accessories | Reviews: 25 | Rating: 4.16/5
# ----------------------------------------------------------------------
# ## AmazonBasics Backpack for Laptops up to 17-inches
#
# **Overall Verdict:** Consider this budget-friendly laptop backpack if you prioritize storage capacity and construction quality over premium materials.
#
# **Strengths:**
# 1. **Well-constructed and sturdy** - Multiple reviewers praised the solid build quality and attention to detail, comparing it favorably to name-brand alternatives
# 2. **Excellent organization** - Features numerous compartments, pockets, and a dedicated organizer section for pens and accessories
# 3. **Versatile capacity** - Large main compartment accommodates 17-inch laptops while serving effectively as an all-purpose backpack
#
# **Weaknesses:**
# 1. **Cheap interior materials** - The inner lining feels flimsy and makes loud "crinkly" sounds when items move around
# 2. **Sizing limitations** - Some thicker 17-inch laptops may not fit properly in the designated compartment
# 3. **Quality control issues** - Reports of zipper problems and minimal padding on the top handle
#
# **Best For:** Budget-conscious users seeking a functional laptop backpack with ample storage for travel, school, or work who can overlook basic material quality in favor of practical organization and solid construction.
#
# *Based on 25 reviews with 4.16/5 average rating*
#
# ======================================================================
# PRODUCT: AmazonBasics 15.6-Inch Laptop and Tablet Bag
# Cluster: Accessories | Reviews: 21 | Rating: 4.52/5
# ----------------------------------------------------------------------
# ## AmazonBasics 15.6-Inch Laptop and Tablet Bag Review Summary
#
# **Overall Verdict:** Buy - This laptop bag offers solid construction and good value at a budget-friendly price point, with 90.5% of customers rating it positively.
#
# **Strengths:**
# 1. **Excellent value for money** - Multiple reviewers praised the quality-to-price ratio, calling it a "great value for a reasonably low price"
# 2. **Well-constructed with good protection** - Features durable materials, quality padding, and comfortable handles that effectively protect laptops
# 3. **Versatile storage options** - Multiple compartments accommodate laptops, tablets, chargers, and accessories, with some users repurposing it as a briefcase
#
# **Weaknesses:**
# 1. **Limited opening mechanism** - The bag only opens about one-third of the way, making laptop insertion awkward compared to fully-opening cases
# 2. **Tight fit concerns** - Some users found the laptop compartment uncomfortably snug for their devices
# 3. **Shoulder strap padding** - Could benefit from additional padding for extended carrying comfort
#
# **Best For:** Budget-conscious buyers seeking a basic, protective laptop bag for occasional use who prioritize value over premium features. Ideal for students or professionals needing reliable protection without advanced functionality.
#
# *Note: Analysis based on limited sample of 21 reviews.*
#
# ======================================================================
# PRODUCT: Kindle Voyage E-reader, 6 High-Resolution Display (300 ppi) with Adapt
# Cluster: E-Readers | Reviews: 505 | Rating: 4.73/5
# ----------------------------------------------------------------------
# ## Kindle Voyage E-reader Review Summary
#
# **Overall Verdict:** Buy - With a 4.73/5 rating and 96.8% positive reviews, this is an excellent premium e-reader despite some quality control concerns.
#
# **Strengths:**
# 1. **Superior display quality** - High-resolution 300 ppi screen with adaptive brightness that automatically adjusts to lighting conditions
# 2. **Premium build and comfort** - Lighter, faster, and more comfortable to hold than previous Kindle models with convenient PagePress sensors
# 3. **Enhanced reading experience** - Crisp text, matte finish ideal for reading, and seamless page turning functionality
#
# **Weaknesses:**
# 1. **Screen uniformity issues** - Multiple users report yellowish/orangish tint at top and bluish tint at bottom of display
# 2. **Durability concerns** - Some units experienced charging failures, software update problems, and screen fragility
# 3. **High price point** - At $199, many question whether the improvements justify the premium over the Paperwhite
#
# **Best For:** Serious readers willing to pay premium prices for the best available e-reading experience, particularly those who read in varying lighting conditions and value automatic brightness adjustment and superior display quality.
#
# *Note: Based on 505 customer reviews with limited negative feedback sample size.*
#
# ======================================================================
# PRODUCT: Kindle E-reader - White, 6 Glare-Free Touchscreen Display, Wi-Fi - Inc
# Cluster: E-Readers | Reviews: 287 | Rating: 4.54/5
# ----------------------------------------------------------------------
# ## Kindle E-reader Review Summary
#
# **Overall Verdict:** Buy - This basic Kindle delivers excellent value with outstanding customer satisfaction (4.54/5 stars, 93.7% positive reviews).
#
# **Strengths:**
# 1. **Exceptional battery life** - Users consistently praise the long-lasting battery that requires infrequent charging
# 2. **Lightweight and portable** - Perfect for travel and daily carry, with a sturdy build quality that withstands regular use
# 3. **Distraction-free reading experience** - No bells and whistles means fewer distractions and better focus on reading
#
# **Weaknesses:**
# 1. **No backlight** - Cannot be used for reading in dark environments without external lighting
# 2. **Screen brightness issues** - Some users report the screen being too dark with no brightness adjustment options
# 3. **Occasional technical problems** - Limited reports of screen failures and charging issues, though these appear to be isolated cases
#
# **Best For:** Budget-conscious readers who primarily read in well-lit environments and value simplicity over advanced features. Ideal for those wanting a dedicated reading device without tablet functionality, frequent travelers, and anyone seeking to minimize reading distractions. Not suitable for nighttime readers or those requiring backlit displays.
#
# *Note: Based on 287 customer reviews with limited negative feedback data available.*
#
# ======================================================================
# PRODUCT: Kindle Oasis E-reader with Leather Charging Cover - Walnut, 6 High-Res
# Cluster: E-Readers | Reviews: 62 | Rating: 4.61/5
# ----------------------------------------------------------------------
# ## Kindle Oasis E-reader Review Summary
#
# **Overall Verdict:** Buy - With a 4.61/5 rating and 96.8% positive reviews, this premium e-reader delivers exceptional reading performance despite its higher price point.
#
# **Strengths:**
# 1. **Superior display quality** - Crystal clear text even in bright sunlight with excellent front lighting distribution
# 2. **Physical page turn buttons** - Highly praised return of tactile controls that prevent accidental page changes
# 3. **Compact, lightweight design** - Comfortable for extended reading sessions across various positions and activities
#
# **Weaknesses:**
# 1. **Magnetic charging cover issues** - Some users report the magnetic connection weakens over time and unsnaps frequently
# 2. **Two-piece design complexity** - Requires managing both the Kindle unit and charging cover separately
# 3. **Limited negative feedback available** - With only 1.6% negative reviews (1 review in sample), comprehensive weakness assessment is challenging
#
# **Best For:** Serious readers willing to invest in premium features who prioritize display quality, physical controls, and portability. Ideal for those who read extensively in various lighting conditions and positions, particularly users upgrading from older Kindle models who missed the physical page turn buttons.
#
# *Note: Analysis based on limited sample size of 62 total reviews.*
#
# ======================================================================
# PRODUCT: Kindle Oasis E-reader with Leather Charging Cover - Black, 6 High-Reso
# Cluster: E-Readers | Reviews: 55 | Rating: 4.62/5
# ----------------------------------------------------------------------
# ## Kindle Oasis E-reader Review Summary
#
# **Overall Verdict:** Buy if you're a serious reader willing to pay premium prices for superior comfort and display quality.
#
# **Strengths:**
# 1. **Exceptional display quality** - Crystal clear text even in bright sunlight with evenly distributed front lighting and 300 ppi resolution
# 2. **Superior ergonomics** - Remarkably lightweight and compact design that's comfortable for extended reading sessions, with physical page-turn buttons that users greatly appreciate
# 3. **Fast performance** - Quick wake-up times and instant book loading for seamless reading experience
#
# **Weaknesses:**
# 1. **High price point** - Significantly more expensive than other Kindle models, making buyers carefully consider the upgrade value
# 2. **Magnetic connector issues** - Some users report the charging cover's magnetic connection weakens over time and unsnaps frequently
# 3. **Two-piece design concerns** - The separate cover creates potential for loss and some users find it flimsy
#
# **Best For:** Dedicated readers who prioritize comfort during long reading sessions and want the best possible e-ink display. Particularly suited for those who miss physical page-turn buttons and read frequently in various lighting conditions.
#
# *Based on 55 reviews with 94.5% positive feedback and 4.62/5 average rating.*
#
# ======================================================================
# PRODUCT: Kindle Oasis E-reader with Leather Charging Cover - Merlot, 6 High-Res
# Cluster: E-Readers | Reviews: 54 | Rating: 4.63/5
# ----------------------------------------------------------------------
# ## Kindle Oasis E-reader Review Summary
#
# **Overall Verdict:** Buy - With a 4.63/5 rating and 96.3% positive reviews, this premium e-reader delivers exceptional reading experience despite the higher price point.
#
# **Strengths:**
# 1. **Superior portability and design** - Reviewers consistently praise its remarkably small, lightweight form factor that fits easily in pockets and small bags
# 2. **Physical page-turn buttons** - Long-time Kindle users appreciate the return of tactile buttons, finding them more reliable than touch-only navigation
# 3. **Enhanced display quality** - The high-resolution screen offers improved clarity and more evenly distributed, whiter front lighting compared to previous models
#
# **Weaknesses:**
# 1. **Premium pricing** - Multiple reviewers note the significantly higher cost compared to other Kindle models makes the purchase decision challenging
# 2. **Charging cover issues** - Some users report the magnetic connector weakens over time and the two-piece design can be cumbersome
# 3. **Battery life concerns** - Limited feedback suggests potential battery performance issues, though data is minimal with only 54 total reviews
#
# **Best For:** Serious readers and Kindle enthusiasts who prioritize portability, premium build quality, and physical controls, and are willing to pay extra for these enhanced features.
#
# ======================================================================
# PRODUCT: Kindle Voyage E-reader, 6 High-Resolution Display (300 ppi) with Adapt
# Cluster: E-Readers | Reviews: 36 | Rating: 4.89/5
# ----------------------------------------------------------------------
# ## Kindle Voyage E-reader Review Summary
#
# **Overall Verdict:** Buy - This premium e-reader delivers exceptional reading quality that justifies its higher price point for serious readers.
#
# **Strengths:**
# 1. **Superior display and lighting** - The high-resolution screen with adaptive backlight provides excellent readability in all conditions, including direct sunlight, without eye strain during extended reading sessions
# 2. **Excellent connectivity options** - Built-in 3G plus Wi-Fi enables convenient book downloads anywhere without needing Wi-Fi hotspots
# 3. **Premium build quality and portability** - Lightweight, durable construction with impressive battery life makes it ideal for travel and daily use
#
# **Weaknesses:**
# 1. **Higher price point** - Multiple reviewers noted the premium cost, though most felt it was justified by the quality
# 2. **Overly sensitive controls** - PagePress sensors can be too responsive, leading to accidental page turns
# 3. **Limited functionality** - Web browser remains experimental and basic compared to tablets
#
# **Best For:** Frequent travelers, library e-book users, and dedicated readers who prioritize eye comfort and connectivity over price. Particularly suited for those who read in varying lighting conditions and want the freedom to download books anywhere.
#
# *Based on 36 reviews with 4.89/5 average rating and 97.2% positive feedback.*
#
# ======================================================================
# PRODUCT: All-New Kindle Oasis E-reader - 7 High-Resolution Display (300 ppi), W
# Cluster: E-Readers | Reviews: 22 | Rating: 4.59/5
# ----------------------------------------------------------------------
# ## Kindle Oasis E-reader Review Summary
#
# **Overall Verdict:** Buy if you're a serious reader seeking premium features, though the high price may deter casual users.
#
# **Strengths:**
# 1. **Superior comfort and ergonomics** - Reviewers consistently praise the comfortable grip and automatic screen rotation that adapts to either hand
# 2. **Excellent display quality** - The 7-inch, 300 ppi high-resolution screen delivers crisp, clear text that reduces eye fatigue
# 3. **Premium features** - Waterproof design and built-in Audible support add versatility for poolside reading and audiobook integration
#
# **Weaknesses:**
# 1. **Initial adjustment period** - The metal back and unique design feel uncomfortable at first, with some users concerned about grip security
# 2. **Intrusive advertising** - Special Offers version displays ads during sleep mode and throughout the store interface
# 3. **High price point** - Expensive for a non-color display device, especially compared to other Kindle models
#
# **Best For:** Dedicated readers who prioritize comfort during long reading sessions, want waterproof functionality for bath/pool use, and don't mind paying premium prices for the best Kindle experience. Less suitable for casual readers who may find better value in the Paperwhite.
#
# *Based on 22 reviews with 4.59/5 average rating and 90.9% positive feedback.*
#
# ======================================================================
# PRODUCT: Fire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Tangerine - with Spe
# Cluster: Fire Tablets | Reviews: 2443 | Rating: 4.6/5
# ----------------------------------------------------------------------
# ## Fire HD 8 Tablet Review Summary
#
# **Overall Verdict:** Buy - This tablet offers excellent value for money, especially for Amazon ecosystem users and casual tablet needs.
#
# **Strengths:**
# 1. **Outstanding value** - Reviewers consistently praise the low price point ($60-89) for the features provided, with many comparing it favorably to more expensive tablets like iPad Mini
# 2. **Strong media performance** - Excellent for streaming shows, reading books, and accessing Amazon's vast content library including free apps, e-books, and games
# 3. **Good build quality and display** - The 8" HD screen performs well for movies and reading, with loud stereo speakers enhancing the media experience
#
# **Weaknesses:**
# 1. **Limited gaming performance** - Struggles with graphics-intensive games, making gameplay "barely playable" on demanding titles
# 2. **Restricted app ecosystem** - No native Google Play Store access (though can be sideloaded), limiting app selection compared to standard Android tablets
# 3. **Technical issues** - Some users report problems with SD card recognition, app crashes, and occasional overheating
#
# **Best For:** Budget-conscious buyers, Amazon Prime members, casual users who primarily stream video and read e-books, and parents seeking affordable tablets for children with robust parental controls.
#
# ======================================================================
# PRODUCT: All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Specia
# Cluster: Fire Tablets | Reviews: 2370 | Rating: 4.58/5
# ----------------------------------------------------------------------
# ## Fire HD 8 Tablet Review Summary
#
# **Overall Verdict:** Buy - This tablet offers excellent value for basic users, with 94.7% positive reviews and strong performance for everyday tasks.
#
# **Strengths:**
# 1. **Outstanding value** - Reviewers consistently praise the low price point, especially during sales (as low as $30-60)
# 2. **Good display and audio** - The 8" HD screen and stereo speakers receive positive feedback for media consumption
# 3. **Solid build quality** - Users report durability and adequate performance for web browsing, streaming, and reading
#
# **Weaknesses:**
# 1. **Limited app ecosystem** - No Google Play Store access out of the box; Amazon's app store has fewer options than standard Android
# 2. **Gaming performance struggles** - Graphics-intensive games run poorly, with reviewers noting barely playable performance
# 3. **Technical issues** - Some users report SD card recognition problems, slow performance, and occasional freezing
#
# **Best For:** Budget-conscious buyers seeking a basic tablet for web browsing, streaming Netflix, reading, and light app usage. Particularly suitable for Amazon ecosystem users and parents looking for affordable tablets with parental controls. Not recommended for power users, serious gamers, or those requiring extensive app selection.
#
# *Based on 2,370 reviews with 4.58/5 average rating*
#
# ======================================================================
# PRODUCT: Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Pink Kid-Proof Case
# Cluster: Fire Tablets | Reviews: 1676 | Rating: 4.53/5
# ----------------------------------------------------------------------
# ## Fire Kids Edition Tablet Review Summary
#
# **Overall Verdict:** Buy - This tablet delivers excellent value for families seeking a durable, child-friendly device with strong parental controls.
#
# **Strengths:**
# 1. **Exceptional durability** - The heavy-duty case withstands drops, impacts, and even teething damage, with reviewers praising its robust construction
# 2. **Outstanding warranty protection** - 2-year no-questions-asked replacement policy covers even cracked screens, providing peace of mind for parents
# 3. **Excellent parental controls** - Individual profiles for each child with age-appropriate content filtering and easy setup make management simple
#
# **Weaknesses:**
# 1. **Limited app ecosystem** - Cannot access Google Play Store or popular apps like YouTube Kids and Netflix, restricting content options significantly
# 2. **Charging port reliability issues** - Multiple reviews mention chronic charging problems that can render the device unusable
# 3. **Subscription costs** - Kid-friendly content is only free for one year, then requires ongoing monthly fees
#
# **Best For:** Parents of children ages 3-10 who prioritize durability and content control over app variety. Ideal for families already invested in Amazon's ecosystem with Prime memberships. Less suitable for tech-savvy older children who expect full Android functionality.
#
# *Based on 1,676 reviews with 4.53/5 average rating*
#
# ======================================================================
# PRODUCT: Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Blue Kid-Proof Case
# Cluster: Fire Tablets | Reviews: 1425 | Rating: 4.53/5
# ----------------------------------------------------------------------
# ## Fire Kids Edition Tablet Review Summary
#
# **Overall Verdict:** Buy - This tablet delivers excellent value for families seeking a durable, child-friendly device with strong parental controls and content access.
#
# **Strengths:**
# 1. **Exceptional durability** - The kid-proof case withstands drops, hard tapping, and even teething damage, with Amazon's 2-year replacement guarantee providing additional peace of mind
# 2. **Comprehensive parental controls** - Easy profile setup allows parents to manage age-appropriate content, control app access, and customize experiences for multiple children
# 3. **Rich content ecosystem** - Amazon Prime membership unlocks extensive libraries of shows, movies, games, and educational apps through the FreeTime platform
#
# **Weaknesses:**
# 1. **Charging port reliability issues** - Multiple reviews mention chronic problems with the charging port failing, requiring replacements
# 2. **Limited app compatibility** - Popular apps like Netflix and Audible have functionality restrictions or don't work properly on the kids' version
# 3. **Performance limitations** - Slower processing speeds and occasional lag when opening apps, particularly frustrating for older children
#
# **Best For:** Families with children ages 3-8 who prioritize durability and content control over high performance, especially Amazon Prime members who can maximize the included content benefits.
#
# ======================================================================
# PRODUCT: Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Green Kid-Proof Cas
# Cluster: Fire Tablets | Reviews: 1212 | Rating: 4.53/5
# ----------------------------------------------------------------------
# ## Fire Kids Edition Tablet Review Summary
#
# **Overall Verdict:** Buy - this tablet delivers solid value for parents seeking a durable, child-friendly device with strong parental controls.
#
# **Strengths:**
# 1. **Exceptional durability** - The heavy-duty protective case withstands drops and rough handling, with Amazon's 2-year replacement warranty providing additional peace of mind
# 2. **Comprehensive parental controls** - Parents can set time limits, control content access, and manage different profiles for multiple children with varying age-appropriate restrictions
# 3. **Kid-optimized experience** - The modified Android system with Amazon features creates an intuitive interface that children can navigate independently
#
# **Weaknesses:**
# 1. **Charging port reliability issues** - Multiple reviews mention chronic problems with the charging port failing, requiring replacements
# 2. **Limited app ecosystem** - No access to popular apps like YouTube Kids or Netflix (with reported functionality issues), restricting entertainment options
# 3. **Subscription dependency** - Many features require ongoing Amazon subscriptions after the first year, adding to long-term costs
#
# **Best For:** Parents of children ages 3-10 who prioritize durability and content control over app variety, and who are comfortable within Amazon's ecosystem for ongoing content subscriptions.
#
# *Based on 1,212 reviews with 4.53/5 average rating*
#
# ======================================================================
# PRODUCT: Fire Tablet, 7 Display, Wi-Fi, 16 GB - Includes Special Offers, Black
# Cluster: Fire Tablets | Reviews: 1024 | Rating: 4.51/5
# ----------------------------------------------------------------------
# ## Fire Tablet 7" Review Summary
#
# **Overall Verdict:** Buy if you're looking for an affordable e-reader and basic tablet primarily for Amazon's ecosystem.
#
# **Strengths:**
# 1. **Excellent value for money** - At $49-69, reviewers consistently praise the unbeatable price point for basic tablet functionality
# 2. **Perfect for reading** - Ideal screen size and performance for Kindle books and e-reading with comfortable eye strain relief
# 3. **Strong parental controls** - Robust child account features with usage timers and content restrictions make it popular with parents
#
# **Weaknesses:**
# 1. **Charging port durability issues** - Multiple reviews mention the charging port breaking or becoming loose within 4-6 months of use
# 2. **Limited performance** - Significant system lag, slow WiFi reception, and poor performance with demanding apps or games
# 3. **Restricted ecosystem** - Lacks Google Play Store access out of the box, limiting app selection to Amazon's marketplace
#
# **Best For:** Budget-conscious buyers seeking an e-reader with basic tablet features, parents wanting an affordable, controllable device for children, and Amazon ecosystem users who primarily consume Amazon content. Not recommended for users wanting a full-featured Android tablet or demanding performance applications.
#
# *Based on 1,024 reviews with 4.51/5 average rating*
#
# ======================================================================
# PRODUCT: Fire Tablet with Alexa, 7 Display, 16 GB, Blue - with Special Offers
# Cluster: Fire Tablets | Reviews: 987 | Rating: 4.51/5
# ----------------------------------------------------------------------
# ## Fire Tablet 7" Review Summary
#
# **Overall Verdict:** Consider this tablet if you're looking for an affordable e-reader and basic media device, but avoid if you need full Android functionality.
#
# **Strengths:**
# 1. **Excellent value for money** - At $49-69, reviewers consistently praise the price-to-performance ratio for basic tasks
# 2. **Great for reading** - Perfect screen size and weight for Kindle books, with good battery life for extended reading sessions
# 3. **Strong parental controls** - Robust child account features with time limits and content restrictions make it ideal for kids
#
# **Weaknesses:**
# 1. **Fragile charging port** - Multiple reviews mention the charging port breaking within 4-6 months, especially with children's use
# 2. **Limited app ecosystem** - No native Google Play Store access frustrates users expecting standard Android apps
# 3. **Poor performance** - Significant system lag, slow WiFi reception, and sluggish web browsing compared to other tablets
#
# **Best For:** Budget-conscious buyers seeking an e-reader with basic tablet features, parents wanting an affordable, controlled device for children, or Amazon ecosystem users who primarily consume Amazon content. Not suitable for users wanting a full-featured Android tablet or demanding performance applications.
#
# *Based on 987 reviews with 4.51/5 average rating*
#
# ======================================================================
# PRODUCT: All-New Fire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Marine Blue
# Cluster: Fire Tablets | Reviews: 883 | Rating: 4.58/5
# ----------------------------------------------------------------------
# ## Fire HD 8 Tablet Review Summary
#
# **Overall Verdict:** Buy - This budget tablet delivers solid value for basic media consumption and casual use, with 93% of users rating it positively.
#
# **Strengths:**
# 1. **Excellent value for money** - Users consistently praise the low price point, especially during sales, making it an affordable option for families or as a backup device
# 2. **Good media performance** - Reviewers highlight its effectiveness for watching videos, reading, and web browsing, with surprisingly decent speakers and Dolby Atmos support
# 3. **Durability** - Multiple reviews mention the tablet's robust build quality, with some users specifically choosing it for children due to its ability to withstand drops and rough handling
#
# **Weaknesses:**
# 1. **Limited 90-day warranty** - Several users expressed disappointment with the short warranty period compared to other devices
# 2. **App compatibility issues** - Some popular apps may not work properly or require workarounds like installing Google Play Store
# 3. **Lower screen resolution** - The 720p display quality falls short compared to premium tablets, particularly noticeable when upgrading from higher-end devices
#
# **Best For:** Budget-conscious buyers seeking a basic tablet for media consumption, reading, light web browsing, or as a durable option for children and elderly users.
#
# ======================================================================
# PRODUCT: Fire Tablet with Alexa, 7 Display, 16 GB, Magenta - with Special Offer
# Cluster: Fire Tablets | Reviews: 745 | Rating: 4.52/5
# ----------------------------------------------------------------------
# ## Fire Tablet 7" Review Summary
#
# **Overall Verdict:** Buy if you need an affordable tablet primarily for reading, basic apps, and media consumption with realistic performance expectations.
#
# **Strengths:**
# 1. **Excellent value** - At $49-69, it delivers solid functionality for the price point, especially for reading Kindle books and basic tasks
# 2. **Great for families** - Robust parental controls, child accounts with time limits, and durable build make it ideal for kids
# 3. **Expandable storage** - MicroSD card support allows users to add significant storage for books, apps, and media
#
# **Weaknesses:**
# 1. **Performance limitations** - Slow processing, system lag, and poor WiFi reception compared to other tablets
# 2. **Charging port durability** - Multiple reviews cite charging port failures after 4-5 months, particularly with children's use
# 3. **Limited app ecosystem** - Restricted to Amazon's app store by default, though Google Play can be sideloaded
#
# **Best For:** Budget-conscious buyers seeking a basic tablet for reading, light web browsing, and media streaming. Particularly suitable for children's first tablet or as a dedicated e-reader with some smart features. Not recommended for users needing robust performance or extensive app selection.
#
# *Based on 745 reviews with 4.52/5 average rating*
#
# ======================================================================
# PRODUCT: All-New Fire HD 8 Kids Edition Tablet, 8 HD Display, 32 GB, Pink Kid-P
# Cluster: Fire Tablets | Reviews: 293 | Rating: 4.64/5
# ----------------------------------------------------------------------
# ## All-New Fire HD 8 Kids Edition Tablet Review Summary
#
# **Overall Verdict:** Buy - With 94.9% positive reviews and a 4.64/5 rating, this tablet delivers excellent value for families seeking a durable, child-friendly device.
#
# **Strengths:**
# 1. **Exceptional durability** - The kid-proof case and rubber bumper effectively protect against drops and spills, with many parents praising its resilience
# 2. **Strong parental controls** - Built-in restrictions prevent in-app purchases and allow parents to set time limits and monitor usage effectively
# 3. **Comprehensive warranty** - The 2-year no-questions-asked replacement policy provides peace of mind for parents dealing with active children
#
# **Weaknesses:**
# 1. **Reliability concerns** - Some units failed within days or weeks of purchase, requiring warranty replacements
# 2. **Performance limitations** - Occasional slowness reported, particularly when running multiple apps or during heavy usage
# 3. **Limited app selection** - Restricted to Amazon's curated app store, which may limit software options compared to other tablets
#
# **Best For:** Parents of children ages 2-8 seeking an affordable, durable tablet with strong parental controls and warranty protection. Ideal for families prioritizing safety features and content management over high-end performance.
#
# *Based on 293 customer reviews*
#
# ======================================================================
# PRODUCT: All-New Fire HD 8 Kids Edition Tablet, 8 HD Display, 32 GB, Blue Kid-P
# Cluster: Fire Tablets | Reviews: 233 | Rating: 4.63/5
# ----------------------------------------------------------------------
# ## Fire HD 8 Kids Edition Tablet Review Summary
#
# **Overall Verdict:** Buy - With a 4.63/5 rating and 91.8% positive reviews, this is a solid choice for parents seeking an affordable, kid-friendly tablet.
#
# **Strengths:**
# 1. **Excellent parental controls** - Multiple user profiles, app time limits, and restricted in-app purchasing give parents comprehensive control over content and usage
# 2. **Great value package** - Includes 2-year warranty, protective case, one year of FreeTime, and no ads, making it cost-effective compared to regular tablets
# 3. **Improved performance** - The 8th generation model offers better battery life (lasting full days) and 32GB storage compared to previous versions
#
# **Weaknesses:**
# 1. **Hardware reliability issues** - Multiple reports of charging port problems, units not turning on, and devices breaking within days or months
# 2. **Performance limitations** - Sluggish navigation, unresponsive touchscreen, and poor camera quality compared to premium tablets
# 3. **Software restrictions** - Limited to Amazon's app store (no Google Play), which can be frustrating for users wanting broader app selection
#
# **Best For:** Budget-conscious parents with young children (ages 2-8) who prioritize safety features and parental controls over premium performance, and don't mind Amazon's ecosystem limitations.
#
# ======================================================================
# PRODUCT: All-New Fire HD 8 Tablet with Alexa, 8 HD Display, 32 GB, Marine Blue
# Cluster: Fire Tablets | Reviews: 160 | Rating: 4.6/5
# ----------------------------------------------------------------------
# ## Fire HD 8 Tablet Review Summary
#
# **Overall Verdict:** Buy - This budget tablet delivers solid value for basic entertainment and reading needs, with 93% of customers rating it positively.
#
# **Strengths:**
# 1. **Exceptional value** - Customers consistently praise the low price point ($50-80) for decent performance and build quality from a reputable brand
# 2. **Expandable storage** - MicroSD card slot allows significant storage expansion, giving it an advantage over iPads in this price range
# 3. **Good performance for the price** - Users report fast operation, decent sound quality, and reasonable battery life for basic tablet functions
#
# **Weaknesses:**
# 1. **Intrusive advertisements** - Multiple reviewers complained about ads appearing every time the device is turned on
# 2. **Limited app ecosystem** - Restricted to Amazon's app store without Google Play access, though some users successfully sideload it
# 3. **Reliability concerns** - Some units experienced charging issues, random lockups, or complete failure within months of purchase
#
# **Best For:** Budget-conscious buyers seeking a basic tablet for reading, streaming, and light entertainment who don't mind Amazon's ecosystem limitations and can tolerate occasional ads. Particularly suitable for children's use or as a secondary device.
#
# *Based on 160 reviews with 4.6/5 average rating*
#
# ======================================================================
# PRODUCT: All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Includes Specia
# Cluster: Fire Tablets | Reviews: 156 | Rating: 4.58/5
# ----------------------------------------------------------------------
# ## Fire HD 8 Tablet Review Summary
#
# **Overall Verdict:** Buy - This budget tablet delivers solid value for basic media consumption and Amazon ecosystem users, with 93.6% positive reviews and a 4.58/5 rating.
#
# **Strengths:**
# 1. **Excellent value for money** - Reviewers consistently praise the tablet's performance relative to its low price point
# 2. **Great for media consumption** - Sharp display, good sound quality, and seamless integration with Amazon Prime content
# 3. **Kid-friendly durability** - Multiple reviews highlight its popularity with children and reliable build quality for family use
#
# **Weaknesses:**
# 1. **Limited app ecosystem** - Fire OS restricts access to Google Play Store and popular apps like Facebook, requiring workarounds
# 2. **Performance limitations** - Some users report slow internet browsing and occasional system shutdowns
# 3. **Hardware reliability concerns** - A few reviews mention premature device failure and SD card slot issues
#
# **Best For:** Budget-conscious buyers seeking a basic tablet for reading, streaming Amazon content, and light browsing. Particularly suitable for families with children or as a secondary device. Not recommended for users requiring full Android app compatibility or demanding performance tasks.
#
# *Based on 156 customer reviews*
#
# ======================================================================
# PRODUCT: Fire HD 8 Tablet with Alexa, 8 HD Display, 32 GB, Tangerine - with Spe
# Cluster: Fire Tablets | Reviews: 156 | Rating: 4.59/5
# ----------------------------------------------------------------------
# ## Fire HD 8 Tablet Review Summary
#
# **Overall Verdict:** Buy - This tablet offers excellent value for money with strong performance for basic media consumption and Amazon ecosystem integration.
#
# **Strengths:**
# 1. **Exceptional value** - Reviewers consistently praise the tablet's performance relative to its affordable price point
# 2. **Great for media consumption** - Excellent for reading, streaming videos, and accessing Amazon Prime content with good screen quality and battery life
# 3. **Kid-friendly** - Multiple reviews highlight how well it works for children, with kids preferring it over gaming systems
#
# **Weaknesses:**
# 1. **Limited app compatibility** - Runs Fire OS instead of standard Android, restricting access to Google Play Store and popular apps like Facebook
# 2. **Performance limitations** - Some users report slow internet browsing and occasional shutdowns during intensive use
# 3. **Hardware reliability concerns** - A few reviews mention device failures and issues with SD card slots
#
# **Best For:** Budget-conscious buyers seeking a basic tablet for reading, streaming Amazon content, and light usage. Particularly suitable for children or as a secondary device for Amazon Prime members. Not recommended for users requiring full Android app compatibility or intensive computing tasks.
#
# *Based on 156 reviews with 4.59/5 average rating*
#
# ======================================================================
# PRODUCT: All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Includes Specia
# Cluster: Fire Tablets | Reviews: 140 | Rating: 4.54/5
# ----------------------------------------------------------------------
# ## Fire HD 8 Tablet Review Summary
#
# **Overall Verdict:** Buy - With 93.6% positive reviews and a 4.54/5 rating, this tablet offers solid value for basic computing needs.
#
# **Strengths:**
# 1. **Excellent value and portability** - Compact 8" size fits easily in purses while delivering good performance for the price point
# 2. **Great for media consumption** - Strong performance for streaming Prime Video, reading, and basic entertainment with good display quality
# 3. **User-friendly for beginners** - Multiple reviewers noted it's easy to navigate, even for older adults and those new to tablets
#
# **Weaknesses:**
# 1. **Limited app ecosystem** - Runs Fire OS instead of standard Android, lacking Google Play Store access and popular apps like Facebook without workarounds
# 2. **Hardware reliability concerns** - Some units experienced premature failure, random shutdowns, and SD card slot defects
# 3. **Performance limitations** - Slower internet browsing and gaming performance compared to premium tablets, with occasional overheating during extended use
#
# **Best For:** Budget-conscious buyers seeking a basic tablet primarily for reading, streaming Amazon content, light web browsing, and simple apps. Ideal for children, seniors, or as a secondary device rather than a primary computing solution.
#
# ======================================================================
# PRODUCT: Amazon Fire HD 8 with Alexa (8" HD Display Tablet)
# Cluster: Fire Tablets | Reviews: 130 | Rating: 4.61/5
# ----------------------------------------------------------------------
# ## Amazon Fire HD 8 with Alexa - Product Summary
#
# **Overall Verdict:** Buy if you need an affordable media consumption tablet and are comfortable with Amazon's ecosystem.
#
# **Strengths:**
# 1. **Excellent value for money** - Reviewers consistently praise its performance relative to the low price point, with many noting it exceeded expectations for basic tasks
# 2. **Great for media consumption** - Users highlight smooth performance for watching videos, reading, and casual internet browsing, making it ideal for couch or bedtime use
# 3. **Seamless Amazon integration** - Books, Prime Video, and other Amazon services sync effortlessly, with Alexa as an added bonus
#
# **Weaknesses:**
# 1. **Limited customization** - The Fire OS interface cannot be significantly modified, frustrating users who want more control
# 2. **Restricted app ecosystem** - App selection is more limited compared to full Android tablets or iPads
# 3. **Basic performance only** - Not suitable for demanding tasks, content creation, or professional work
#
# **Best For:** Budget-conscious buyers seeking a secondary device for media streaming, e-reading, casual web browsing, and light gaming. Particularly well-suited for Amazon Prime members, children, or older adults who prioritize simplicity over advanced features.
#
# *Based on 130 reviews with 4.61/5 average rating and 96.2% positive feedback.*
#
# ======================================================================
# PRODUCT: All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Includes Specia
# Cluster: Fire Tablets | Reviews: 115 | Rating: 4.57/5
# ----------------------------------------------------------------------
# ## Fire HD 8 Tablet Review Summary
#
# **Overall Verdict:** Buy - This budget tablet delivers solid value for basic media consumption and Amazon ecosystem users, with 92% of customers satisfied.
#
# **Strengths:**
# 1. **Excellent value for money** - Reviewers consistently praise the tablet's performance relative to its low price point
# 2. **Great for media consumption** - Sharp display, good sound quality, and seamless integration with Amazon Prime content
# 3. **Kid-friendly and durable** - Multiple parents report children preferring it over gaming systems, with good build quality
#
# **Weaknesses:**
# 1. **Limited app compatibility** - Runs Fire OS instead of standard Android, blocking access to Google Play Store, Facebook, and iTunes without workarounds
# 2. **Performance issues** - Some users report slow internet browsing and occasional reliability problems
# 3. **Amazon ecosystem lock-in** - Designed primarily for Amazon services, which may frustrate users wanting broader functionality
#
# **Best For:** Budget-conscious buyers seeking a basic tablet for reading, streaming Amazon content, and light browsing. Particularly suitable for children, seniors, or as a secondary device. Avoid if you need full Android app compatibility or plan to use non-Amazon services extensively.
#
# *Based on 115 reviews with 4.57/5 average rating*
#
# ======================================================================
# PRODUCT: Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 GB - Includes Special Of
# Cluster: Fire Tablets | Reviews: 99 | Rating: 4.59/5
# ----------------------------------------------------------------------
# ## Fire HD 10 Tablet Review Summary
#
# **Overall Verdict:** Buy - With a 4.59/5 rating and 89.9% positive reviews, this tablet delivers solid value for basic computing needs.
#
# **Strengths:**
# 1. **Excellent display and size** - Users consistently praise the 10.1" screen for easy reading and viewing, with good visual quality for media consumption
# 2. **Strong Amazon ecosystem integration** - Prime members appreciate seamless access to free music, movies, TV shows, and offline content options
# 3. **User-friendly and reliable performance** - Reviewers find it intuitive to set up and use, with fast, dependable operation for everyday tasks
#
# **Weaknesses:**
# 1. **Poor battery life** - Multiple users report disappointing battery performance, with some experiencing only 3-4 hours of use and frequent charging needs
# 2. **Awkward portability** - The larger 10.1" size makes it cumbersome to hold for extended periods and less convenient for travel
# 3. **Inconsistent web browsing** - Some users experience slow page loading and sluggish internet performance despite strong WiFi connections
#
# **Best For:** Amazon Prime members seeking an affordable media consumption device for home use, particularly those who prioritize screen size for reading, streaming, and basic productivity tasks over portability.
#
# ======================================================================
# PRODUCT: All-New Fire 7 Tablet with Alexa, 7" Display, 8 GB - Marine Blue
# Cluster: Fire Tablets | Reviews: 82 | Rating: 4.59/5
# ----------------------------------------------------------------------
# ## Fire 7 Tablet Review Summary
#
# **Overall Verdict:** Buy if you need a basic, budget-friendly tablet for simple tasks and entertainment.
#
# **Strengths:**
# 1. **Excellent value for money** - Multiple reviewers praised the low price point, especially when on sale for $30-50
# 2. **Long battery life** - Users consistently noted impressive battery performance for extended use
# 3. **Clear display quality** - Screen resolution exceeded expectations for the price range
#
# **Weaknesses:**
# 1. **Slow performance** - Several users reported sluggish operation and frequent buffering
# 2. **Limited storage** - 8GB capacity requires memory card expansion for additional apps/content
# 3. **Build quality concerns** - Some reports of cracking and connectivity issues with smart TVs
#
# **Best For:** Budget-conscious buyers seeking a basic tablet for reading, light gaming, social media, and video streaming. Particularly suitable for children, seniors, or anyone wanting an affordable secondary device without advanced features. Not recommended for users who need fast performance or plan to run multiple demanding applications.
#
# *Based on 82 reviews with 4.59/5 average rating and 90.2% positive feedback.*
#
# ======================================================================
# PRODUCT: All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Specia
# Cluster: Fire Tablets | Reviews: 67 | Rating: 4.52/5
# ----------------------------------------------------------------------
# ## Fire HD 8 Tablet Review Summary
#
# **Overall Verdict:** Buy if you're an Amazon Prime member seeking an affordable entertainment tablet, but consider alternatives for productivity needs.
#
# **Strengths:**
# 1. **Excellent value** - Reviewers consistently praise the tablet's performance and features relative to its low price point
# 2. **Great for media consumption** - Clear HD display and seamless integration with Amazon Prime for streaming movies and content
# 3. **User-friendly setup** - Easy to configure and use, even for those who typically avoid technology
#
# **Weaknesses:**
# 1. **Reliability concerns** - Multiple reports of devices completely failing with blank screens after short periods of use
# 2. **Limited app ecosystem** - Restricted to Amazon's app store rather than full Android compatibility, limiting functionality
# 3. **Forced advertisements** - Lock screen displays ads that cannot be customized with personal photos
#
# **Best For:** Amazon Prime members wanting an affordable tablet primarily for reading, streaming videos, light gaming, and basic web browsing. Not recommended for users seeking productivity features or those who need access to the full Google Play Store. The reliability issues make it a risky choice despite the attractive price point.
#
# *Based on 67 reviews with 4.52/5 average rating*

# %% [markdown]
# ## 7. Save All Summaries

# %%
# Save as JSON for the web app
output = {
    "provider": PROVIDER,
    "model": MODELS[PROVIDER],
    "cluster_summaries": cluster_summaries,
    "product_summaries": product_summaries
}

with open("../data/summaries_api.json", "w", encoding="utf-8") as f:
    json.dump(output, f, indent=2, ensure_ascii=False)

print(f"Saved to summaries_api.json")
print(f"  Cluster summaries: {len(cluster_summaries)}")
print(f"  Product summaries: {len(product_summaries)}")
# Out:
# Saved to summaries_api.json
#   Cluster summaries: 6
#   Product summaries: 33

# %%
# Also save as a readable markdown report
md_lines = []
md_lines.append("# Amazon Product Review Summaries")
md_lines.append(f"\n*Generated with {MODELS[PROVIDER]} ({PROVIDER})*\n")
md_lines.append("---\n")

# Cluster summaries
for cluster_name, summary in cluster_summaries.items():
    md_lines.append(f"## {cluster_name}\n")
    md_lines.append(summary)
    md_lines.append("\n---\n")

# Product summaries
md_lines.append("# Individual Product Summaries\n")

current_cluster = None
for product_name, data in product_summaries.items():
    if data["cluster"] != current_cluster:
        current_cluster = data["cluster"]
        md_lines.append(f"\n## {current_cluster}\n")
    
    md_lines.append(f"### {product_name[:70]}")
    md_lines.append(f"*{data['stats']['total_reviews']} reviews | "
                    f"Avg {data['stats']['avg_rating']}/5 | "
                    f"{data['stats']['pct_positive']}% positive*\n")
    md_lines.append(data["summary"])
    md_lines.append("\n")

report_md = "\n".join(md_lines)

with open("../docs/summaries_report.md", "w", encoding="utf-8") as f:
    f.write(report_md)

print(f"Saved to summaries_report.md ({len(report_md):,} chars)")
# Out:
# Saved to summaries_report.md (70,879 chars)

# %% [markdown]
# ## 8. Cost Estimate

# %%
# Cost summary
# The rough estimation below is based on actual Anthropic console data.
# Input tokens are much larger than output because we send review samples in each prompt.

total_calls = len(cluster_summaries) + len(product_summaries)

total_output_chars = 0
for summary in cluster_summaries.values():
    total_output_chars += len(summary)
for data in product_summaries.values():
    total_output_chars += len(data["summary"])

print(f"Total API calls: {total_calls}")
print(f"Total output chars: {total_output_chars:,}")
print(f"\nActual cost (from Anthropic console): ~$0.43 USD")
print(f"  This covers both input tokens (review samples in prompts)")
print(f"  and output tokens ({total_calls} summaries generated)")
print(f"\nFor reference - approximate per-call cost: ~${0.43/total_calls:.3f}")
# Out:
# Total API calls: 39
# Total output chars: 66,552
#
# Actual cost (from Anthropic console): ~$0.43 USD
#   This covers both input tokens (review samples in prompts)
#   and output tokens (39 summaries generated)
#
# For reference - approximate per-call cost: ~$0.011

# %% [markdown]
# ## 9. Summary
#
# ### Method
# - Sampled representative reviews per product (positive, negative, neutral)
# - Prioritized longer, more informative reviews (min 5 words, sorted by length)
# - Sent product stats + sample reviews to LLM with structured prompts
# - Generated both category-level overview articles and individual product summaries
#
# ### Results
# - **6 cluster summaries** — one recommendation article per category (~600 words each)
# - **33 product summaries** — individual verdict/strengths/weaknesses for products with 20+ reviews
# - **39 total API calls** at a cost of **$0.43 USD** (Anthropic Claude Sonnet)
# - ~$0.011 per summary — very cost-effective
#
# ### Provider
# - Used: **Anthropic Claude Sonnet** (`claude-sonnet-4-20250514`)
# - Switchable to OpenAI GPT-4o-mini via `PROVIDER` flag (would cost ~$0.01-0.02 total)
# - Temperature: 0.3 for consistent, factual output
#
# ### Files Produced
# - `summaries_api.json` — structured data for the web app (cluster + product summaries)
# - `summaries_report.md` — readable markdown report with all summaries (70,879 chars)
#
# ### Notes
# - Products with < 20 reviews were excluded from individual summaries (insufficient data)
# - The cost estimate in v1 of this notebook was incorrect (only counted output tokens). Actual cost confirmed via Anthropic console: $0.43 for all 39 calls
